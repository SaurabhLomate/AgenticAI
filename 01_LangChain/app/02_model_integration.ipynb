# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# #### gemini

# %%
from langchain.chat_models import init_chat_model

google_model1 = init_chat_model(model="google_genai:gemini-3.6-flash")
google_model1
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.5.1', 'langchain': '1.3.14', 'langchain-google-genai': '4.3.1'}}, output_version=None, profile={'name': 'Gemini 3.6 Flash', 'release_date': '2026-07-21', 'last_updated': '2026-07-21', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'medium'}, google_api_key=SecretStr('**********'), location=None, model='gemini-3.6-flash', temperature=None, client=<google.genai.client.Client object at 0x00000226B8511CF0>, def
# ...

# %%
google_response1 = google_model1.invoke("What is AI?")
google_response1.content[0]['text']
# Out:
# '**Artificial Intelligence (AI)** is a branch of computer science focused on creating systems and machines capable of performing tasks that would typically require human intelligence. \n\nThese tasks include **learning, reasoning, problem-solving, understanding natural language, recognizing patterns, and making decisions.**\n\nInstead of being explicitly programmed with rigid rules for every possible scenario, modern AI learns from vast amounts of data to make predictions, generate content, or take actions.\n\n---\n\n### How Does AI Work?\nAt its core, AI works by combining large datasets with intelligent algorithms (sets of instructions). It processes this data, identifies underlying patterns, and uses those patterns to solve problems or improve its own performance over time.\n\nKey concepts within AI include:\n* **Machine Learning (ML):** A subset of AI where systems automatically learn and improve from experience without being explicitly programmed.\n* **Deep Learning:** A subset 
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

google_model2 = ChatGoogleGenerativeAI(
    model = "gemini-3.6-flash"
)
google_response2 = google_model2.invoke("What is AI?")
google_response2.content[0]['text']
# Out:
# '**Artificial Intelligence (AI)** refers to the development of computer systems that can perform tasks that would typically require human intelligence. These tasks include learning, reasoning, problem-solving, understanding natural language, recognizing patterns, and making decisions.\n\nInstead of following a rigid set of pre-written rules, AI systems analyze vast amounts of data to learn how to accomplish tasks on their own.\n\n---\n\n### How Does AI Work?\n\nAt its core, AI works by combining **large datasets** with **smart algorithms** (sets of instructions) that allow the software to learn automatically from patterns or features in the data. \n\nTo understand modern AI, it helps to know three key terms:\n\n1. **Machine Learning (ML):** A branch of AI where computers are fed data and "learn" to improve at a task over time without being explicitly programmed for every outcome. (e.g., teaching a computer to spot spam emails by showing it millions of examples).\n2. **Deep Learning:*
# ...
