# %% [markdown]
# ### LangChain Expression Language (LCEL)
# LCEL is a declarative way to connect LangChain components into a pipeline using the | operator.

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# #### chat prompt template

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Explain {topic}")

# %% [markdown]
# #### model

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model= "llama-3.3-70b-versatile")

# %% [markdown]
# #### output parser

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %% [markdown]
# #### chain

# %%
chain = prompt | model | parser

response = chain.invoke({
    "topic":"Runnable in Langchain"
})

print(response)
# Out:
# **Runnable in Langchain**
# ========================
#
# Langchain is a framework for building applications that involve large language models. In Langchain, a `Runnable` is a fundamental concept that represents a self-contained unit of work that can be executed by the framework.
#
# **Definition**
# -------------
#
# A `Runnable` is an abstract class in Langchain that defines a set of methods that must be implemented by any concrete subclass. The primary method is `run()`, which contains the logic that is executed when the `Runnable` is invoked.
#
# **Purpose**
# ------------
#
# The purpose of a `Runnable` is to encapsulate a specific task or operation that can be executed independently. This allows Langchain to manage the execution of multiple tasks concurrently, improving overall system performance and scalability.
#
# **Key Characteristics**
# ----------------------
#
# Here are some key characteristics of a `Runnable` in Langchain:
#
# *   **Self-contained**: A `Runnable` is a self-contained unit of work that does not depend on external state or context.
# *   **Executable**: A `Runnable` can be executed independently by the Langchain framework.
# *   **Reusable**: A `Runnable` can be reused multiple times with different input parameters.
#
# **Example Use Case**
# --------------------
#
# Here is an example of a simple `Runnable` in Langchain that generates text using a language model:
# ```python
# from langchain import Runnable
#
# class TextGenerator(Runnable):
#     def __init__(self, model, prompt):
#         self.model = model
#         self.prompt = prompt
#
#     def run(self):
#         # Generate text using the language model
#         text = self.model.generate_text(self.prompt)
#         return text
#
# # Create a TextGenerator Runnable
# generator = TextGenerator(model="my_model", prompt="Hello World")
#
# # Execute the Runnable
# result = generator.run()
# print(result)
# ```
# In this example, the `TextGenerator` class is a concrete implementation of the `Runnable` abstract class. The `run()` method generates text using a language model and returns the result.
#
# **Best Practices**
# ------------------
#
# Here are some best practices to keep in mind when working with `Runnable` in Langchain:
#
# *   Keep `Runnable` instances self-contained and independent to ensure efficient execution.
# *   Use `Runnable` instances to encapsulate specific tasks or operations that can be reused multiple times.
# *   Avoid sharing state or context between `Runnable` instances to prevent concurrency issues.

# %%
for chunk in chain.stream({"topic":"StrOutputParser in langchain"}):
    print(chunk, end="", flush=True)
# Out:
# `StrOutputParser` is a class in the LangChain library, which is a framework for building and interacting with large language models.
#
# The primary function of `StrOutputParser` is to parse the output of a language model when it is given a string input. This output can be in various forms, such as text, JSON, or other formats. The parser's role is to extract the relevant information from the output and present it in a more structured and usable format.
#
# Here are some key features and uses of `StrOutputParser`:
#
# 1. **Text extraction**: The parser can extract specific text patterns or substrings from the output, allowing you to isolate the most relevant information.
# 2. **JSON parsing**: If the output is in JSON format, the parser can parse it and extract specific fields or values, making it easier to work with the data.
# 3. **Error handling**: The parser can also handle errors that may occur during the parsing process, such as malformed output or unexpected formats.
# 4. **Customization**: `StrOutputParser` can be customized to suit specific use cases or requirements, allowing you to define your own parsing rules and logic.
#
# Some common use cases for `StrOutputParser` include:
#
# 1. **Natural Language Processing (NLP)**: The parser can be used to extract specific information from text output, such as entities, keywords, or sentiment analysis results.
# 2. **Conversational AI**: The parser can help process user input and extract relevant information, such as intent, entities, or context, to inform the conversational flow.
# 3. **Data extraction**: The parser can be used to extract specific data points or patterns from text output, such as names, dates, or numbers.
#
# To use `StrOutputParser` in LangChain, you would typically:
#
# 1. Import the `StrOutputParser` class from the LangChain library.
# 2. Create an instance of the parser, passing in any required configuration or customization options.
# 3. Pass the output of the language model to the parser, either as a string or a JSON object.
# 4. Use the parsed output to extract the relevant information, such as text patterns, JSON fields, or other data points.
#
# Here's an example code snippet to illustrate the usage of `StrOutputParser`:
# ```python
# from langchain import StrOutputParser
#
# # Create a language model output
# output = "The answer is 42, and the reason is because it's a great number."
#
# # Create an instance of the parser
# parser = StrOutputParser()
#
# # Parse the output
# parsed_output = parser.parse(output)
#
# # Extract the relevant information
# answer = parsed_output.extract("answer")
# reason = parsed_output.extract("reason")
#
# print(f"Answer: {answer}, Reason: {reason}")
# ```
# Note that this is a simplified example, and the actual usage of `StrOutputParser` may vary depending on the specific requirements and use case.
