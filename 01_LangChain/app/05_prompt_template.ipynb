# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate.from_template("Explain {topic} in simple words.")

prompt = template.invoke({"topic":"langchain"})

print(prompt)
# Out:
# text='Explain langchain in simple words.'

# %% [markdown]
# #### Partial Variables
#
# - Sometimes a value never changes.
# - Instead of repeatedly passing, you can pre-fill part of the template.

# %%
template = PromptTemplate(
    template= "Explain {topic} in {language}",
    input_variables=['topic'],
    partial_variables={
        "language":"english"
    }
)

prompt = template.invoke({"topic":"langchain"})
print(prompt)
# Out:
# text='Explain langchain in english'

# %% [markdown]
# #### promptTemplate with model

# %%
from langchain_groq import ChatGroq
template = PromptTemplate(
    template="""Teach {subject} to a {level} student in {language}.""",
    input_variables = ['subject','level'],
    partial_variables={
        "language":"English"
    }
)
prompt = template.invoke({
    "subject":"Langchain",
    "level" :"beginner"
})
# print(prompt)

model = ChatGroq(model= "llama-3.3-70b-versatile")

response = model.invoke(prompt)
print(response.content)
# Out:
# Welcome to Langchain, a powerful tool for building and interacting with large language models. I'm excited to help you get started with Langchain.
#
# **What is Langchain?**
#
# Langchain is an open-source framework that allows you to build, train, and interact with large language models. It provides a simple and flexible way to work with language models, making it easier to develop and deploy language-based applications.
#
# **Key Concepts**
#
# Before we dive into the details, let's cover some key concepts:
#
# 1. **Language Models**: A language model is a type of artificial intelligence (AI) that can understand and generate human-like language. Think of it like a super-smart chatbot that can have conversations with you.
# 2. **Chain**: In Langchain, a chain refers to a sequence of language models that work together to generate text. Think of it like a team of language models that collaborate to produce a response.
# ...
