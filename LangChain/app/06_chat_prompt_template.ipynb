# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

msg_template = ChatPromptTemplate.from_messages(
    [
        ("system", "you are a ai developer"),
        ("human","{question}")
    ]
)

prompt = msg_template.invoke({
    "question":"explain langchain vs langgraph in 2 lines"
})

print(prompt)
# Out:
# messages=[SystemMessage(content='you are a ai developer', additional_kwargs={}, response_metadata={}), HumanMessage(content='explain langchain vs langgraph in 2 lines', additional_kwargs={}, response_metadata={})]

# %%
model = ChatGroq(model= "llama-3.3-70b-versatile")

response = model.invoke(prompt)
print(response.content)
# Out:
# LangChain and LangGraph are both AI frameworks, with LangChain focusing on building applications using large language models, while LangGraph is a library for creating and working with graph-based language models. LangGraph provides a more structured approach to representing knowledge, whereas LangChain is more flexible and application-oriented.
